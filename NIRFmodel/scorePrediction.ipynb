# %%
import pandas as pd
import numpy as np
import json
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
data=pd.read_csv("FinalDataset.csv")

# %%
def loadModel(Z):
  X=data.iloc[:,6:11]
  y=data.iloc[:, 4]
  X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=20)
  regressor=LinearRegression()
  regressor.fit(X_train, y_train)
  y_pred=regressor.predict(Z)
  return y_pred

# %%
def predict(params):
  Y=np.array([[params["TLR"], params["RPC"], params["GO"], params["OI"], params["PERCEPTION"]]])
  score=loadModel(Y)
  return score[0]

# %%
def inputValues(params):
# tlr=float(input("enter tlr"))
# rpc=float(input("enter rpc"))
# go=float(input("enter go"))
# oi=float(input("enter oi"))
# perc=float(input("enter perc"))
  # params={"TLR": tlr,
  #         "RPC":rpc,
  #         "GO":go,
  #         "OI": oi,
  #         "PERCEPTION": perc}
  values=json.load(params)
  print(predict(values))
